# %% [markdown]
# # Google Search  Analysis
#
# Approximately 3.5 billion searches area permormed every second on Google. So Google search is a great use case for analyzing data based on search queries.
#
# Original project Aman Kharwal

# %% [markdown]
# Google doesn´t give much access to the data about daily search queries, but another application of google konw as google Trends can be used for the task of google search analysis. Google Trends provides and API that can be used to analyze the daily searches on Google. This API is known as pytrends, you can easily install it in your systems by using the commmand: py install pytrends

# %%
# import the libraries

import pandas as pd
from pytrends.request import TrendReq
import time
import matplotlib.pyplot as plt
trends = TrendReq()

# %% [markdown]
# Here we will be analyzing the Google search trends on the queries based on "Data Analyst", So let's create a DataFrame of the top 10 countries which search for "Data Analyst" on Google:

# %%
pytrends = TrendReq(hl='en-US', tz=360)

trends.build_payload(kw_list=["Machine Learning"])

time.sleep(5)

data = trends.interest_by_region()
data = data.sort_values(by="Machine Learning", ascending=False)
data = data.head(10)
print(data)
# Out:
#              Machine Learning
# geoName
# China                     100
# Ethiopia                   56
# Singapore                  53
# India                      44
# Tunisia                    31
# Sri Lanka                  31
# Pakistan                   30
# South Korea                29
# Hong Kong                  28
# Kenya                      26

# %% [markdown]
# So, according to the above results, the search queries based on "Machine learning" are mostly done in China. We can also visualize this data using a bard chart

# %%
data.reset_index().plot(x="geoName",
                        y="Machine Learning",
                        figsize=(15,12), kind="bar")
plt.style.use('fivethirtyeight')
plt.show()

# %% [markdown]
# So as we all know that Machine Learning has been the focus of so many companies and students for the last 3-4 years, so let's have a look at the trend of searches to see how the total search queries based on "Machine Learning" increased or decreased on Google:

# %%
data = TrendReq(hl='en-US', tz=360)
data.build_payload(kw_list=['Machine Learning'])

data = data.interest_over_time()

time.sleep(30)

fig, ax = plt.subplots(figsize=(15, 12))

data['Machine Learning'].plot(ax=ax)

plt.style.use('fivethirtyeight')
plt.title('Total Google Searches for Machine Learning', fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Total Count')
plt.show()

# %% [markdown]
# # Conclusion
#
# So we can see a huge increase in the searches about "machine learning" on Google in 2022. This is how we can analyze Google searches based on a any keyword. A business can perform Google search analysis to understand what people are looking for on Google Search analysis to understand what people are looking for on Google at any given time.
